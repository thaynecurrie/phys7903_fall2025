# %% [markdown]
# # _Python for Scientific Data Analysis_
#
#
# #  AstroPy and AstroQuery
#
# ## Section 3: AstroQuery

# %% [markdown]
# A lot of what it means to "do" astronomy involves querying public databases and downloading data from these sources.   And there are a TON of them: HST, JWST, Gaia, 2MASS, Keck, etc.   Just wait until we have LSST.
#
# Astronomy/astrophysics is a data-rich, highly accessible field (as science *should* be: not all fields are like this).   E.g. in principle, any rando anywhere in the world can download public data from many ground-based and basically all space-based observatories -- usually after some proprietary period of 6 to 18 months -- and make scientific discoveries.
#
# E.g. I know of a few cases where -- with some cursory background in coding, statistics and knowing how to navigate the Internet -- someone could have discovered a directly imaged planet from publicly accessible data!
#
# So how do you access all of these data?   In many cases, you have to do it manually.   But for a lot of data --especially those contained in catalogues, fully reduced and analyzed -- you can use **astroquery**.

# %% [markdown]
# Astroquery is a set of tools for querying astronomical web forms and databases.   It is an _affiliated package_ of AstroPy (more on that in Section 4).  For now, that means that you have to download and install astroquery separately from the core astropy package.  To do that, at Terminal you need to use either conda or pip ...

# %% [markdown]
# #pip
#
# ``pip install astroquery``
#
# #conda
#
# ``conda install -c conda-forge astroquery``

# %% [markdown]
# There are two other packages with complimentary functionality as Astroquery: pyvo is an Astropy affiliated package, and Simple-Cone-Search-Creator to generate a cone search service complying with the IVOA standard. They are more oriented to general virtual observatory discovery and queries, whereas Astroquery has web service specific interfaces.
#
# To use astroquery, we start with our same basic import functions we used for astropy:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# To these we add the astroquery import function

# %%
import astroquery

# %% [markdown]
# is the most basic import command.  But usually we want to import specific catalogues/servers from which astroquery will pull data.  E.g.

# %%
from astroquery.simbad import Simbad #Simbad astronomical database
from astroquery.vizier import Vizier #Vizier database

# %% [markdown]
# Let's start with these two catalog queries. These are some that are the most common ones you will want to deal with.  What are they?
#
# * **Simbad** - SIMBAD (the Set of Identifications, Measurements and Bibliography for Astronomical Data) is an astronomical database of extrasolar objects beyond the Solar System.  [http://simbad.u-strasbg.fr/simbad/]()
#
# * **Vizier** - The VizieR Catalogue Service is an astronomical catalog service.   [https://vizier.cds.unistra.fr/viz-bin/VizieR]()
#
# The simplistic but helpful way of thinking about this is that Simbad will pull information for individual objects whereas Vizier details with different catalogues.
#
# ### Major Types of Queries
#
# There are multiple ways of querying these data sources for objects or data properties.   But two chief ones you will be interested in are ``query_object`` and ``query_region``.   The purpose of these are fairly straightforward to understand.
#
# To run, do
#
# ``variable=Simbad.query_object([object name])``
#
# ``variable=Simbad.query_region([coordinates],r=[radius])``
#
# etc.
#
# For ``query_object``, the [object name] simply needs to be in single or double quotes (i.e. that it is a string variable).
#
# You can then subscript the variable storing the query by keywords to extract parameters
#
# Below are some examples of basic queries of the Simbad and Vizier databases ...

# %% [markdown]
# ### Simbad

# %%
#convert from coordinates in simbad to a coordinate object
#c=coordinates.SkyCoord(Angle(var['RA']+' hours'),Angle(var['DEC'] + ' degrees'))

#A Simple Query

starname='hr 8799'  #HR 8799
result=Simbad.query_object(starname)
result
#result[0] #prints out the same thing here
# Out:
# <Table length=1>
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
#   object      str13         str13     ...        object            int32
# --------- ------------- ------------- ... ------------------- ----------------
# HD 218396 23 07 28.7157 +21 08 03.310 ... 2020yCat.1350....0G                1

# %% [markdown]
# after querying Simbad for this object, you can then return specific values listed:

# %%
print(result['RA'][0]) #result[0]['RA'] also works here.  it means you are selecting the 0th row of the 'RA' column
#'23 07 28.7157'

print(result['DEC'][0])
#'+21 08 03.310'

print(result['COO_BIBCODE'][0]) #bibliography code

#lists all of the column names
result.colnames
# Out:
# 23 07 28.7157
# +21 08 03.310
# 2020yCat.1350....0G
# ['MAIN_ID',
#  'RA',
#  'DEC',
#  'RA_PREC',
#  'DEC_PREC',
#  'COO_ERR_MAJA',
#  'COO_ERR_MINA',
#  'COO_ERR_ANGLE',
#  'COO_QUAL',
#  'COO_WAVELENGTH',
#  'COO_BIBCODE',
#  'SCRIPT_NUMBER_ID']

# %% [markdown]
# Compare the information listed in ``result`` with a manual search for the same object on the Simbad webpage.   You will likely see that the webpage entry contains a lot more information missing in the table.  To be able to extract this information using astroquery, you need to add the variable in question to the possible fields.
#
# To figure out the fields you can use, execute ``Simbad.list_votable_fields()``, which lists the possible table fields.

# %%
print(Simbad.list_votable_fields())
# Out:
# --NOTES--
#
# 1. The parameter filtername must correspond to an existing filter. Filters include: B,V,R,I,J,K.  They are checked by SIMBAD but not astroquery.simbad
#
# 2. Fields beginning with rvz display the data as it is in the database. Fields beginning with rv force the display as a radial velocity. Fields beginning with z force the display as a redshift
#
# 3. For each measurement catalog, the VOTable contains all fields of the first measurement. When applicable, the first measurement is the mean one.
#
# Available VOTABLE fields:
#
# bibcodelist(y1-y2)
# biblio
# cel
# cl.g
# coo(opt)
# coo_bibcode
# coo_err_angle
# coo_err_maja
# coo_err_mina
# coo_qual
# coo_wavelength
# coordinates
# dec(opt)
# dec_prec
# diameter
# dim
# dim_angle
# dim_bibcode
# dim_incl
# dim_majaxis
# dim_minaxis
# dim_qual
# dim_wavelength
# dimensions
# distance
# distance_result
# einstein
# fe_h
# flux(filtername)
# flux_bibcode(filtername)
# flux_error(filtername)
# flux_name(filtername)
# flux_qual(filtername)
# flux_system(filtername)
# flux_unit(filtername)
# fluxdata(filtername)
# gcrv
# gen
# gj
# hbet
# hbet1
# hgam
# id(opt)
# ids
# iras
# irc
# iso
# iue
# jp11
# link_bibcode
# main_id
# measurements
# membership
# mesplx
# mespm
# mk
# morphtype
# mt
# mt_bibcode
# mt_qual
# otype
# otype(opt)
# otypes
# parallax
# plx
# plx_bibcode
# plx_error
# plx_prec
# plx_qual
# pm
# pm_bibcode
# pm_err_angle
# pm_err_maja
# pm_err_mina
# pm_qual
# pmdec
# pmdec_prec
# pmra
# pmra_prec
# pos
# posa
# propermotions
# ra(opt)
# ra_prec
# rot
# rv_value
# rvz_bibcode
# rvz_error
# rvz_qual
# rvz_radvel
# rvz_type
# rvz_wavelength
# sao
# sp
# sp_bibcode
# sp_nature
# sp_qual
# sptype
# td1
# typed_id
# ubv
# uvby
# uvby1
# v*
# velocity
# xmm
# z_value
# For more information on a field:
# Simbad.get_field_description ('field_name')
# Currently active VOTABLE fields:
#  ['main_id', 'coordinates']
# None

# %% [markdown]
# You can then add fields using ``Simbad.add_votable_fields([field name])``.    Here are examples ...

# %%
Simbad.add_votable_fields('flux(J)','flux(H)','flux(K)') #adds J, H, and K band photometry from 2MASS
Simbad.add_votable_fields('sp') #adds the spectral type
Simbad.add_votable_fields('plx')

# %% [markdown]
# Then the revised query looks like the following ...

# %%
result=Simbad.query_object(starname)
print(result[0])
result
# Out:
#  MAIN_ID        RA           DEC      RA_PREC DEC_PREC COO_ERR_MAJA COO_ERR_MINA COO_ERR_ANGLE COO_QUAL COO_WAVELENGTH     COO_BIBCODE     FLUX_J FLUX_H FLUX_K  SP_TYPE   PLX_VALUE SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"                         mas          mas           deg                                                   mag    mag    mag                 mas
# --------- ------------- ------------- ------- -------- ------------ ------------ ------------- -------- -------------- ------------------- ------ ------ ------ ---------- --------- ----------------
# HD 218396 23 07 28.7157 +21 08 03.310      14       14        0.037        0.040            90        A              O 2020yCat.1350....0G  5.383   5.28   5.24 F0+VkA5mA5    24.462                1
# <Table length=1>
#  MAIN_ID        RA           DEC      ...  SP_TYPE   PLX_VALUE SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...               mas
#   object      str13         str13     ...   object    float64       int32
# --------- ------------- ------------- ... ---------- --------- ----------------
# HD 218396 23 07 28.7157 +21 08 03.310 ... F0+VkA5mA5    24.462                1

# %% [markdown]
# See that we've now added the four columns.    We can extract their values.  But first we need to know the names of teh columns to extract.  The mapping from the strings contained in "add votable fields" to the metadata for the table sometimes isn't one to one.
#
# Thankfully, you can see the names of the columns and then figure out which one corresponds to which intended field that you added.  See below ...

# %%
result[0].colnames
# Out:
# ['MAIN_ID',
#  'RA',
#  'DEC',
#  'RA_PREC',
#  'DEC_PREC',
#  'COO_ERR_MAJA',
#  'COO_ERR_MINA',
#  'COO_ERR_ANGLE',
#  'COO_QUAL',
#  'COO_WAVELENGTH',
#  'COO_BIBCODE',
#  'FLUX_J',
#  'FLUX_H',
#  'FLUX_K',
#  'SP_TYPE',
#  'PLX_VALUE',
#  'SCRIPT_NUMBER_ID']

# %% [markdown]
# So, "Flux J" is the J band magnitude that we added as a votable field, etc etc.
#
# Now, we can extract values

# %%
spt=result['SP_TYPE'][0]
#spt #'F0+VkA5mA5'

jmag=result['FLUX_J'][0]
hmag=result['FLUX_H'][0]
kmag=result['FLUX_K'][0]
plx=result['PLX_VALUE'][0]

print(jmag,hmag,kmag)
print(spt)
print(plx)
# Out:
# 5.383 5.28 5.24
# F0+VkA5mA5
# 24.462

# %% [markdown]
# The coordinate query returns strings for right ascension and declination.  With a bit of trickery you can turn this into a coordinate object in Astropy and save in units of degrees ...

# %%
import astropy.units as u
from astropy import coordinates 
from astropy.coordinates import SkyCoord
from astropy.coordinates import Angle

ra=result['RA'][0]
dec=result['DEC'][0]

c=coordinates.SkyCoord(Angle(ra +' hours'),Angle(dec + ' degrees'))
#c=coordinates.SkyCoord(Angle(ra +' hours'),Angle(dec + ' degrees'))
#c=coordinates.SkyCoord(Angle(ra),Angle(dec)) #this doesn't work

print(ra)
print(dec)
print('and now c ')
print(c)
print(c.ra)
print(c.dec)
# Out:
# 23 07 28.7157
# +21 08 03.310
# and now c
# <SkyCoord (ICRS): (ra, dec) in deg
#     (346.86964875, 21.13425278)>
# 346d52m10.7355s
# 21d08m03.31s

# %% [markdown]
# For a coordinate query, you are searching for objects around your target within some radius

# %%
result2=Simbad.query_region(c,radius=10*u.arcminute)

########to sort based on distance away, create a new SkyCoord object ...#####

coords=SkyCoord(result2['RA'],result2['DEC'],unit=(u.hourangle,u.deg))
angsep=c.separation(coords)*3600 #to arc-seconds 

###method 1
# Add the separation as a new column
#result2['separation'] = angsep
#result2.sort('separation')
#result2


##method 2
#result2.sort(angsep.argsort())
result2f=result2[angsep.argsort()]

# %%
result2f
# Out:
# <Table length=36>
#           MAIN_ID                  RA      ... PLX_VALUE SCRIPT_NUMBER_ID
#                                 "h:m:s"    ...    mas
#            object                str13     ...  float64       int32
# ---------------------------- ------------- ... --------- ----------------
#                   HD 218396c 23 07 28.7157 ...    24.462                1
#                   HD 218396d 23 07 28.7157 ...    24.462                1
#                   HD 218396b 23 07 28.7157 ...    24.462                1
#                   HD 218396f 23 07 28.7157 ...    24.462                1
#                   HD 218396e 23 07 28.7157 ...    24.462                1
#                    HD 218396 23 07 28.7157 ...    24.462                1
#               TYC 1718-851-1 23 07 24.5842 ...     2.100                1
#     SDSS J230725.90+210459.0 23 07 25.9082 ...     0.144                1
#      2MASS J23072914+2112041 23 07 29.1381 ...     1.476                1
#                          ...           ... ...       ...              ...
#     SDSS J230719.19+211610.8  23 07 19.194 ...        --                1
#     SDSS J230712.15+211544.7 23 07 12.1607 ...        --                1
#           PGCC G092.59-35.55       23 06.9 ...        --                1
#     SDSS J230728.66+205905.7 23 07 28.6648 ...        --                1
# Gaia DR3 2838464587946419840 23 08 08.9199 ...     0.600                1
#     SDSS J230747.30+211639.5 23 07 47.3094 ...        --                1
#     SDSS J230658.31+211435.6 23 06 58.3147 ...        --                1
#     SDSS J230710.33+205917.2 23 07 10.3376 ...     0.244                1
#                TYC 1718-21-1 23 06 59.5219 ...     0.974                1

# %% [markdown]
# Now see that we have a lot more entries as we are searching for everything within a few arc-minutes.  To select out targets you do index slicing ...

# %%
name_result2=result2f['MAIN_ID'][8]
print(name_result2)

jmag_result2=result2f['FLUX_J'][0:11]
print(jmag_result2)
print(len(jmag_result2))
# Out:
# 2MASS J23072914+2112041
# FLUX_J
#  mag
# ------
#     --
#     --
#     --
#     --
#     --
#  5.383
#  7.574
# 15.071
# 14.867
#     --
#     --
# 11

# %% [markdown]
# ### Vizier
#
#
# The simplest form of a Vizier query involves searching for data for a given object within a catalogue, searchable either on the object name itself or around its coordinates.  Here are some examples

# %%
#simple example: search all catalogues
result3=Vizier.query_object("HIP 99770")
result3
#result3[0]
# Out:
# WARNING: UnitsWarning: The unit 'G' has been deprecated in the VOUnit standard. Suggested: 0.0001T. [astropy.units.format.vounit]
# TableList with 371 tables:
# 	'0:I/34/greenw2a' with 16 column(s) and 1 row(s)
# 	'1:I/34/greenw2b' with 17 column(s) and 1 row(s)
# 	'2:I/45/catalog' with 12 column(s) and 1 row(s)
# 	'3:I/61B/agk3' with 15 column(s) and 1 row(s)
# 	'4:I/100A/w50' with 9 column(s) and 1 row(s)
# 	'5:I/113A/catalog' with 10 column(s) and 1 row(s)
# 	'6:I/122/bd' with 9 column(s) and 1 row(s)
# 	'7:I/131A/sao' with 11 column(s) and 1 row(s)
# 	'8:I/146/ppm1' with 12 column(s) and 1 row(s)
# 	'9:I/171/acrs1' with 14 column(s) and 1 row(s)
# 	'10:I/182/pacp4' with 7 column(s) and 1 row(s)
# 	'11:I/196/main' with 14 column(s) and 1 row(s)
# 	'12:I/196/annex1' with 10 column(s) and 2 row(s)
# 	'13:I/197A/tic' with 10 column(s) and 1 row(s)
# 	'14:I/238A/picat' with 15 column(s) and 1 row(s)
# 	'15:I/239/hip_main' with 14 column(s) and 1 row(s)
# 	'16:I/239/tyc_main' with 11 column(s) and 1 row(s)
# 	'17:I/243/out' with 8 column(s) and 25 row(s)
# 	'18:I/246/act' with 8 column(s) and 1 row(s)
# 	'19:I/250/catalog' with 10 column(s) and 1 row(s)
# 	'20:I/252/out' with 8 column(s) and 25 row(s)
# 	'21:I/254/out' with 10 column(s) and 3 row(s)
# 	'22:I/255/out' with 9 column(s) and 3 row(s)
# 	'23:I/256/stars' with 9 column(s) and 1 row(s)
# 	'24:I/256/varpos' with 9 column(s) and 1 row(s)
# 	'25:I/259/tyc2' with 10 column(s) and 1 row(s)
# 	'26:I/260/ccdmhipn' with 11 column(s) and 2 row(s)
# 	'27:I/270/cpirss01' with 8 column(s) and 1 row(s)
# 	'28:I/271/out' with 11 column(s) and 50 row(s)
# 	'29:I/274/ccdm' with 13 column(s) and 2 row(s)
# 	'30:I/275/ac2002' with 9 column(s) and 3 row(s)
# 	'31:I/276/catalog' with 15 column(s) and 1 row(s)
# 	'32:I/280B/ascc' with 12 column(s) and 1 row(s)
# 	'33:I/283A/npm2' with 11 column(s) and 1 row(s)
# 	'34:I/284/out' with 14 column(s) and 43 row(s)
# 	'35:I/294A/ucac2bss' with 12 column(s) and 1 row(s)
# 	'36:I/297/out' with 19 column(s) and 50 row(s)
# 	'37:I/304/out' with 9 column(s) and 50 row(s)
# 	'38:I/305/out' with 11 column(s) and 50 row(s)
# 	'39:I/306A/stars' with 20 column(s) and 4 row(s)
# 	'40:I/311/hip2' with 13 column(s) and 1 row(s)
# 	'41:I/312/sample' with 13 column(s) and 5 row(s)
# 	'42:I/317/sample' with 13 column(s) and 35 row(s)
# 	'43:I/319/xpm' with 25 column(s) and 20 row(s)
# 	'44:I/322A/out' with 24 column(s) and 50 row(s)
# 	'45:I/324/igsl3' with 18 column(s) and 50 row(s)
# 	'46:I/327/cmc15' with 9 column(s) and 50 row(s)
# 	'47:I/328/table1' with 17 column(s) and 1 row(s)
# 	'48:I/329/urat1' with 16 column(s) and 50 row(s)
# 	'49:I/333/upc' with 20 column(s) and 1 row(s)
# 	'50:I/337/gaia' with 14 column(s) and 50 row(s)
# 	'51:I/339/hsoy' with 18 column(s) and 27 row(s)
# 	'52:I/340/ucac5' with 20 column(s) and 50 row(s)
# 	'53:I/342/f3' with 18 column(s) and 8 row(s)
# 	'54:I/345/gaia2' with 32 column(s) and 50 row(s)
# 	'55:I/347/gaia2dis' with 9 column(s) and 50 row(s)
# 	'56:I/348/catalog' with 35 column(s) and 2 row(s)
# 	'57:I/349/starhorse' with 19 column(s) and 50 row(s)
# 	'58:I/350/gaiaedr3' with 39 column(s) and 50 row(s)
# 	'59:I/350/tyc2tdsc' with 16 column(s) and 1 row(s)
# 	'60:I/350/comscanl' with 13 column(s) and 1 row(s)
# 	'61:I/351/gps1_p' with 22 column(s) and 45 row(s)
# 	'62:I/352/gedr3dis' with 10 column(s) and 50 row(s)
# 	'63:I/353/gsc242' with 35 column(s) and 50 row(s)
# 	'64:I/354/starhorse2021' with 20 column(s) and 50 row(s)
# 	'65:I/355/gaiadr3' with 57 column(s) and 50 row(s)
# 	'66:I/355/paramp' with 24 column(s) and 50 row(s)
# 	'67:I/355/paramsup' with 24 column(s) and 50 row(s)
# 	'68:I/355/epphot' with 48 column(s) and 50 row(s)
# 	'69:I/355/xpsummary' with 22 column(s) and 50 row(s)
# 	'70:I/355/xpsample' with 6 column(s) and 50 row(s)
# 	'71:I/355/xpcont' with 26 column(s) and 50 row(s)
# 	'72:I/355/spectra' with 5 column(s) and 13 row(s)
# 	'73:I/356/qsocand' with 10 column(s) and 1 row(s)
# 	'74:I/358/varisum' with 24 column(s) and 4 row(s)
# 	'75:I/358/vclassre' with 6 column(s) and 4 row(s)
# 	'76:I/358/veb' with 25 column(s) and 2 row(s)
# 	'77:I/360/goldf' with 23 column(s) and 1 row(s)
# 	'78:I/360/goldoba' with 4 column(s) and 2 row(s)
# 	'79:I/360/syntphot' with 5 column(s) and 50 row(s)
# 	'80:I/363/gaia_rv_dr3' with 17 column(s) and 11 row(s)
# 	'81:II/5A/data' with 10 column(s) and 1 row(s)
# 	'82:II/6/catalog' with 31 column(s) and 1 row(s)
# 	'83:II/7A/catalog' with 17 column(s) and 1 row(s)
# 	'84:II/8/mean' with 12 column(s) and 1 row(s)
# 	'85:II/26A/catalog' with 20 column(s) and 1 row(s)
# 	'86:II/38/ph18' with 20 column(s) and 1 row(s)
# 	'87:II/38/ph31' with 10 column(s) and 1 row(s)
# 	'88:II/59B/catalog' with 20 column(s) and 1 row(s)
# 	'89:II/62/catalog' with 14 column(s) and 1 row(s)
# 	'90:II/84/catalog' with 23 column(s) and 1 row(s)
# 	'91:II/122B/merged' with 12 column(s) and 8 row(s)
# 	'92:II/125/main' with 13 column(s) and 2 row(s)
# 	'93:II/157A/catalog' with 10 column(s) and 2 row(s)
# 	'94:II/167/catalog' with 8 column(s) and 2 row(s)
# 	'95:II/168/ubvmeans' with 15 column(s) and 1 row(s)
# 	'96:II/215/catalog' with 18 column(s) and 1 row(s)
# 	'97:II/224/cadars' with 12 column(s) and 2 row(s)
# 	'98:II/225/catalog' with 14 column(s) and 16 row(s)
# 	'99:II/225/names' with 5 column(s) and 1 row(s)
# 	'100:II/225/psc' with 8 column(s) and 1 row(s)
# 	'101:II/226/catalog' with 10 column(s) and 1 row(s)
# 	'102:II/237/colors' with 14 column(s) and 1 row(s)
# 	'103:II/246/out' with 15 column(s) and 50 row(s)
# 	'104:II/269/catal' with 12 column(s) and 1 row(s)
# 	'105:II/297/irc' with 13 column(s) and 1 row(s)
# 	'106:II/311/wise' with 22 column(s) and 49 row(s)
# 	'107:II/316/gps6' with 17 column(s) and 50 row(s)
# 	'108:II/321/iphas2' with 11 column(s) and 50 row(s)
# 	'109:II/328/allwise' with 28 column(s) and 50 row(s)
# 	'110:II/336/apass9' with 19 column(s) and 6 row(s)
# 	'111:II/338/catalog' with 23 column(s) and 2 row(s)
# 	'112:II/345/jmdc' with 16 column(s) and 1 row(s)
# 	'113:II/346/jsdc_v2' with 30 column(s) and 1 row(s)
# 	'114:II/349/ps1' with 35 column(s) and 50 row(s)
# 	'115:II/354/hipext' with 12 column(s) and 1 row(s)
# 	'116:II/360/catalog' with 21 column(s) and 35 row(s)
# 	'117:II/361/mdfc-v10' with 22 column(s) and 1 row(s)
# 	'118:II/363/unwise' with 11 column(s) and 50 row(s)
# 	'119:II/365/catwise' with 38 column(s) and 50 row(s)
# 	'120:II/366/catv2021' with 30 column(s) and 2 row(s)
# 	'121:II/368/sstsl2' with 37 column(s) and 50 row(s)
# 	'122:II/374/table2' with 11 column(s) and 50 row(s)
# 	'123:II/389/ps1_dr2' with 35 column(s) and 50 row(s)
# 	'124:III/4/catalog' with 22 column(s) and 1 row(s)
# 	'125:III/18B/mkclass' with 12 column(s) and 3 row(s)
# 	'126:III/21/gcrv' with 13 column(s) and 1 row(s)
# 	'127:III/39A/catalog' with 17 column(s) and 1 row(s)
# 	'128:III/42/catalog' with 12 column(s) and 1 row(s)
# 	'129:III/48B/catalog' with 11 column(s) and 1 row(s)
# 	'130:III/53/catalog' with 10 column(s) and 1 row(s)
# 	'131:III/78/mkext' with 11 column(s) and 1 row(s)
# 	'132:III/121/catalog' with 17 column(s) and 7 row(s)
# 	'133:III/126/stars' with 6 column(s) and 1 row(s)
# 	'134:III/126/part1' with 11 column(s) and 1 row(s)
# 	'135:III/126/part3' with 11 column(s) and 1 row(s)
# 	'136:III/135A/catalog' with 17 column(s) and 1 row(s)
# 	'137:III/148A/table1' with 8 column(s) and 2 row(s)
# 	'138:III/148A/table3' with 10 column(s) and 1 row(s)
# 	'139:III/190B/web' with 16 column(s) and 1 row(s)
# 	'140:III/208/catalog' with 14 column(s) and 1 row(s)
# 	'141:III/213/catalog' with 12 column(s) and 1 row(s)
# 	'142:III/231/catalog' with 11 column(s) and 1 row(s)
# 	'143:III/244/catalog' with 11 column(s) and 11 row(s)
# 	'144:III/249/catalog' with 14 column(s) and 2 row(s)
# 	'145:III/252/table8' with 12 column(s) and 1 row(s)
# 	'146:III/254/crvad2' with 12 column(s) and 1 row(s)
# 	'147:III/284/allstars' with 99 column(s) and 1 row(s)
# 	'148:III/284/allvis' with 10 column(s) and 4 row(s)
# 	'149:III/286/catalog' with 92 column(s) and 1 row(s)
# 	'150:III/286/allvis' with 22 column(s) and 4 row(s)
# 	'151:IV/25/tyc2_hd' with 14 column(s) and 1 row(s)
# 	'152:IV/27A/catalog' with 13 column(s) and 1 row(s)
# 	'153:IV/30/stars' with 14 column(s) and 2 row(s)
# 	'154:IV/35/wn18_b10' with 18 column(s) and 50 row(s)
# 	'155:IV/38/tic' with 48 column(s) and 50 row(s)
# 	'156:IV/39/tic82' with 48 column(s) and 50 row(s)
# 	'157:V/14/catalog' with 16 column(s) and 1 row(s)
# 	'158:V/15/catalog' with 12 column(s) and 1 row(s)
# 	'159:V/24/cstar' with 12 column(s) and 1 row(s)
# 	'160:V/30/catalog' with 13 column(s) and 1 row(s)
# 	'161:V/50/catalog' with 11 column(s) and 1 row(s)
# 	'162:V/51/disco' with 10 column(s) and 5 row(s)
# 	'163:V/53A/catalog' with 13 column(s) and 1 row(s)
# 	'164:V/98/msx' with 11 column(s) and 1 row(s)
# 	'165:V/114/msx6_gp' with 16 column(s) and 1 row(s)
# 	'166:V/133/kic' with 14 column(s) and 50 row(s)
# 	'167:V/136/tycall' with 14 column(s) and 1 row(s)
# 	'168:V/137D/XHIP' with 15 column(s) and 1 row(s)
# 	'169:V/145/sky2kv5' with 13 column(s) and 1 row(s)
# 	'170:V/155/gdr2ap' with 22 column(s) and 16 row(s)
# 	'171:V/158/morxv2' with 30 column(s) and 1 row(s)
# 	'172:V/160/shboost' with 18 column(s) and 50 row(s)
# 	'173:V/165/igapsdr1' with 17 column(s) and 50 row(s)
# 	'174:VI/32/data1' with 14 column(s) and 1 row(s)
# 	'175:VI/42/out' with 3 column(s) and 1 row(s)
# 	'176:VI/110/inescat' with 7 column(s) and 13 row(s)
# 	'177:VI/111/isolog' with 7 column(s) and 5 row(s)
# 	'178:VI/135/table15' with 15 column(s) and 1 row(s)
# 	'179:VII/285/gdr2ext' with 7 column(s) and 1 row(s)
# 	'180:VII/293/catalog' with 14 column(s) and 29 row(s)
# 	'181:VIII/65/nvss' with 12 column(s) and 2 row(s)
# 	'182:VIII/106/hppsc070' with 20 column(s) and 1 row(s)
# 	'183:VIII/106/hpesl' with 14 column(s) and 1 row(s)
# 	'184:VIII/106/hprsl' with 5 column(s) and 8 row(s)
# 	'185:IX/50/xmm3r6s' with 17 column(s) and 3 row(s)
# 	'186:IX/54/xmm3r7s' with 17 column(s) and 3 row(s)
# 	'187:IX/55/xmm3r8s' with 17 column(s) and 3 row(s)
# 	'188:IX/58/2sxps' with 12 column(s) and 1 row(s)
# 	'189:IX/59/xmm4dr9s' with 17 column(s) and 3 row(s)
# 	'190:IX/61/xmm4r9st' with 23 column(s) and 6 row(s)
# 	'191:IX/63/xmm4d10s' with 16 column(s) and 3 row(s)
# 	'192:IX/64/xmm410st' with 23 column(s) and 6 row(s)
# 	'193:IX/65/xmm4d11s' with 16 column(s) and 3 row(s)
# 	'194:IX/66/xmm411st' with 23 column(s) and 6 row(s)
# 	'195:IX/68/xmm4d12s' with 16 column(s) and 3 row(s)
# 	'196:IX/69/xmm4d13s' with 16 column(s) and 3 row(s)
# 	'197:B/cfht/obscore' with 11 column(s) and 50 row(s)
# 	'198:B/cfht/cfht' with 8 column(s) and 50 row(s)
# 	'199:B/eso/eso_arc' with 8 column(s) and 4 row(s)
# 	'200:B/mk/mktypes' with 11 column(s) and 17 row(s)
# 	'201:B/gcvs/gcvs_cat' with 11 column(s) and 1 row(s)
# 	'202:B/wds/wds' with 18 column(s) and 5 row(s)
# 	'203:B/vsx/vsx' with 20 column(s) and 6 row(s)
# 	'204:B/pastel/pastel' with 16 column(s) and 4 row(s)
# 	'205:B/assocdata/obscore' with 13 column(s) and 1 row(s)
# 	'206:B/gemini/obscore' with 11 column(s) and 50 row(s)
# 	'207:B/dao/obscore' with 11 column(s) and 1 row(s)
# 	'208:B/polarbase/polarbase' with 11 column(s) and 10 row(s)
# 	'209:J/ApJ/694/1085/table1' with 12 column(s) and 1 row(s)
# 	'210:J/ApJ/703/L72/2mass' with 10 column(s) and 1 row(s)
# 	'211:J/ApJ/737/45/table1' with 8 column(s) and 2 row(s)
# 	'212:J/ApJ/762/88/members' with 18 column(s) and 1 row(s)
# 	'213:J/ApJ/804/146/table5' with 16 column(s) and 1 row(s)
# 	'214:J/ApJ/823/114/table1' with 13 column(s) and 1 row(s)
# 	'215:J/ApJ/826/171/table3' with 11 column(s) and 1 row(s)
# 	'216:J/ApJ/836/34/table2' with 10 column(s) and 1 row(s)
# 	'217:J/ApJ/858/L7/table2' with 13 column(s) and 1 row(s)
# 	'218:J/ApJ/861/149/table3' with 14 column(s) and 1 row(s)
# 	'219:J/ApJ/867/105/refcat2' with 23 column(s) and 50 row(s)
# 	'220:J/ApJ/878/21/table1' with 19 column(s) and 1 row(s)
# 	'221:J/ApJ/879/69/table2' with 26 column(s) and 1 row(s)
# 	'222:J/ApJ/900/4/table3' with 19 column(s) and 1 row(s)
# 	'223:J/ApJ/929/33/table2' with 12 column(s) and 1 row(s)
# 	'224:J/ApJ/984/58/table1' with 9 column(s) and 37 row(s)
# 	'225:J/ApJS/176/276/stars' with 14 column(s) and 1 row(s)
# 	'226:J/ApJS/245/13/table1' with 24 column(s) and 2 row(s)
# 	'227:J/ApJS/254/42/catalog' with 29 column(s) and 1 row(s)
# 	'228:J/ApJS/264/41/catalog' with 30 column(s) and 1 row(s)
# 	'229:J/ApJS/268/4/table2' with 49 column(s) and 1 row(s)
# 	'230:J/ApJS/276/15/table4' with 31 column(s) and 1 row(s)
# 	'231:J/ApJS/276/15/table5' with 19 column(s) and 1 row(s)
# 	'232:J/A+A/331/633/table1' with 11 column(s) and 3 row(s)
# 	'233:J/A+A/352/555/table1' with 12 column(s) and 1 row(s)
# 	'234:J/A+A/373/625/table2' with 12 column(s) and 1 row(s)
# 	'235:J/A+A/393/897/table5' with 11 column(s) and 1 row(s)
# 	'236:J/A+A/393/897/table9' with 8 column(s) and 1 row(s)
# 	'237:J/A+A/398/1121/catalog' with 24 column(s) and 1 row(s)
# 	'238:J/A+A/407/631/tablea1' with 11 column(s) and 1 row(s)
# 	'239:J/A+A/411/447/table1' with 14 column(s) and 1 row(s)
# 	'240:J/A+A/412/447/table4' with 18 column(s) and 1 row(s)
# 	'241:J/A+A/463/671/table4' with 8 column(s) and 1 row(s)
# 	'242:J/A+A/469/1221/catalog' with 11 column(s) and 1 row(s)
# 	'243:J/A+A/531/A165/param' with 15 column(s) and 1 row(s)
# 	'244:J/A+A/537/A120/table1' with 16 column(s) and 1 row(s)
# 	'245:J/A+A/546/A61/tablea1' with 18 column(s) and 1 row(s)
# 	'246:J/A+A/548/A97/table1' with 21 column(s) and 2 row(s)
# 	'247:J/A+A/553/A95/table5' with 7 column(s) and 1 row(s)
# 	'248:J/A+A/556/A52/table70' with 8 column(s) and 1 row(s)
# 	'249:J/A+A/580/A23/catalog' with 24 column(s) and 1 row(s)
# 	'250:J/A+A/594/A116/nhi_hpx' with 6 column(s) and 1 row(s)
# 	'251:J/A+A/596/A49/maincat' with 12 column(s) and 1 row(s)
# 	'252:J/A+A/617/A32/list' with 5 column(s) and 1 row(s)
# 	'253:J/A+A/618/A93/members' with 16 column(s) and 2 row(s)
# 	'254:J/A+A/620/A172/ums' with 24 column(s) and 1 row(s)
# 	'255:J/A+A/623/A72/hipgpma' with 42 column(s) and 1 row(s)
# 	'256:J/A+A/628/A67/catalog' with 11 column(s) and 1 row(s)
# 	'257:J/A+A/629/A139/table3' with 16 column(s) and 1 row(s)
# 	'258:J/A+A/633/A99/members' with 13 column(s) and 2 row(s)
# 	'259:J/A+A/635/A45/table2' with 15 column(s) and 1 row(s)
# 	'260:J/A+A/638/A21/sample' with 17 column(s) and 23 row(s)
# 	'261:J/A+A/638/A76/apogee' with 14 column(s) and 1 row(s)
# 	'262:J/A+A/640/A1/nodup' with 16 column(s) and 1 row(s)
# 	'263:J/A+A/646/A104/membersl' with 14 column(s) and 8 row(s)
# 	'264:J/A+A/648/A44/tabled1' with 41 column(s) and 15 row(s)
# 	'265:J/A+A/649/A6/table1c' with 31 column(s) and 1 row(s)
# 	'266:J/A+A/650/A112/target' with 28 column(s) and 1 row(s)
# 	'267:J/A+A/650/A112/filtered' with 28 column(s) and 1 row(s)
# 	'268:J/A+A/653/A98/aspic1_1' with 23 column(s) and 1 row(s)
# 	'269:J/A+A/657/A7/tablea1' with 52 column(s) and 1 row(s)
# 	'270:J/A+A/657/A7/tablea2' with 43 column(s) and 1 row(s)
# 	'271:J/A+A/657/A7/tablea3' with 43 column(s) and 1 row(s)
# 	'272:J/A+A/657/A138/table6' with 13 column(s) and 1 row(s)
# 	'273:J/A+A/657/A138/table7' with 13 column(s) and 3 row(s)
# 	'274:J/A+A/659/A95/sos' with 12 column(s) and 3 row(s)
# 	'275:J/A+A/659/A95/apogee' with 18 column(s) and 1 row(s)
# 	'276:J/A+A/661/A89/table1' with 36 column(s) and 1 row(s)
# 	'277:J/A+A/669/A104/catalog' with 37 column(s) and 11 row(s)
# 	'278:J/A+A/673/A155/apogee17' with 12 column(s) and 1 row(s)
# 	'279:J/A+A/674/A22/catalog' with 7 column(s) and 2 row(s)
# 	'280:J/A+A/674/A25/vspursig' with 40 column(s) and 4 row(s)
# 	'281:J/A+A/675/A68/members' with 11 column(s) and 50 row(s)
# 	'282:J/A+A/677/A137/catalog' with 30 column(s) and 50 row(s)
# 	'283:J/A+A/678/A111/astars' with 31 column(s) and 13 row(s)
# 	'284:J/A+A/678/A158/catalog' with 13 column(s) and 1 row(s)
# 	'285:J/A+A/683/A49/tablea1' with 16 column(s) and 1 row(s)
# 	'286:J/A+A/685/A59/catalog' with 18 column(s) and 1 row(s)
# 	'287:J/A+A/685/A66/age_cat' with 27 column(s) and 1 row(s)
# 	'288:J/A+A/687/A250/catalog' with 26 column(s) and 2 row(s)
# 	'289:J/A+A/688/A203/bshrcds' with 14 column(s) and 1 row(s)
# 	'290:J/A+A/689/A270/table2' with 12 column(s) and 1 row(s)
# 	'291:J/A+A/689/A302/tableb1' with 5 column(s) and 1 row(s)
# 	'292:J/A+A/690/A54/a2g' with 15 column(s) and 1 row(s)
# 	'293:J/A+A/691/A242/tessobaf' with 15 column(s) and 1 row(s)
# 	'294:J/A+A/692/A115/pristine_ca' with 13 column(s) and 50 row(s)
# 	'295:J/A+A/692/A150/allskytg' with 16 column(s) and 1 row(s)
# 	'296:J/A+A/692/A150/lopn1tg' with 16 column(s) and 1 row(s)
# 	'297:J/A+A/697/A165/table2' with 7 column(s) and 1 row(s)
# 	'298:J/A+A/700/A195/catalog' with 24 column(s) and 1 row(s)
# 	'299:J/A+A/701/A270/catalog' with 10 column(s) and 2 row(s)
# 	'300:J/A+AS/101/551/table1' with 13 column(s) and 1 row(s)
# 	'301:J/A+AS/106/21/table1' with 11 column(s) and 2 row(s)
# 	'302:J/A+AS/109/201/table1' with 9 column(s) and 1 row(s)
# 	'303:J/A+AS/123/93/table1' with 10 column(s) and 5 row(s)
# 	'304:J/A+AS/144/469/table1' with 8 column(s) and 1 row(s)
# 	'305:J/AJ/132/50/table2' with 13 column(s) and 35 row(s)
# 	'306:J/AJ/145/132/table3' with 18 column(s) and 1 row(s)
# 	'307:J/AJ/150/141/urhip' with 11 column(s) and 1 row(s)
# 	'308:J/AJ/151/59/table1' with 11 column(s) and 1 row(s)
# 	'309:J/AJ/153/16/table3' with 14 column(s) and 1 row(s)
# 	'310:J/AJ/153/95/table3' with 17 column(s) and 1 row(s)
# 	'311:J/AJ/154/115/table2' with 8 column(s) and 1 row(s)
# 	'312:J/AJ/158/93/table2' with 5 column(s) and 46 row(s)
# 	'313:J/AJ/158/187/table3' with 13 column(s) and 1 row(s)
# 	'314:J/AJ/159/84/table2' with 5 column(s) and 46 row(s)
# 	'315:J/AJ/159/166/table2' with 18 column(s) and 1 row(s)
# 	'316:J/AJ/159/182/table4' with 13 column(s) and 1 row(s)
# 	'317:J/AJ/160/68/table1' with 53 column(s) and 3 row(s)
# 	'318:J/AJ/160/68/table2' with 11 column(s) and 3 row(s)
# 	'319:J/AJ/160/279/table1' with 4 column(s) and 1 row(s)
# 	'320:J/AJ/161/234/table2' with 62 column(s) and 2 row(s)
# 	'321:J/AJ/161/234/table3' with 17 column(s) and 7 row(s)
# 	'322:J/AJ/161/234/table4' with 19 column(s) and 3 row(s)
# 	'323:J/AJ/161/234/table6' with 21 column(s) and 20 row(s)
# 	'324:J/AJ/163/152/table1' with 12 column(s) and 1 row(s)
# 	'325:J/AJ/165/267/table1' with 27 column(s) and 1 row(s)
# 	'326:J/AJ/166/236/table4' with 8 column(s) and 1 row(s)
# 	'327:J/AJ/166/236/table6' with 11 column(s) and 1 row(s)
# 	'328:J/AJ/167/139/t_hpic' with 96 column(s) and 1 row(s)
# 	'329:J/PASP/120/1128/catalog' with 15 column(s) and 1 row(s)
# 	'330:J/PASP/126/469/polar' with 11 column(s) and 1 row(s)
# 	'331:J/PASP/129/E4501/table1' with 10 column(s) and 1 row(s)
# 	'332:J/PASP/137/A4402/list2025' with 10 column(s) and 1 row(s)
# 	'333:J/MNRAS/371/703/catalog' with 14 column(s) and 1 row(s)
# 	'334:J/MNRAS/374/664/tablea1' with 16 column(s) and 1 row(s)
# 	'335:J/MNRAS/389/869/table2' with 14 column(s) and 1 row(s)
# 	'336:J/MNRAS/394/1338/tablea2' with 12 column(s) and 1 row(s)
# 	'337:J/MNRAS/403/1089/table4' with 10 column(s) and 1 row(s)
# 	'338:J/MNRAS/414/1227/table4' with 13 column(s) and 1 row(s)
# 	'339:J/MNRAS/427/343/table2' with 13 column(s) and 1 row(s)
# 	'340:J/MNRAS/427/2917/table2' with 17 column(s) and 1 row(s)
# 	'341:J/MNRAS/437/1216/vast' with 21 column(s) and 1 row(s)
# 	'342:J/MNRAS/454/593/table1' with 21 column(s) and 1 row(s)
# 	'343:J/MNRAS/456/3655/table2' with 11 column(s) and 1 row(s)
# 	'344:J/MNRAS/460/3179/table3' with 10 column(s) and 1 row(s)
# 	'345:J/MNRAS/463/4210/ucac4rpm' with 12 column(s) and 3 row(s)
# 	'346:J/MNRAS/465/3879/table1' with 15 column(s) and 1 row(s)
# 	'347:J/MNRAS/466/546/table1' with 18 column(s) and 1 row(s)
# 	'348:J/MNRAS/471/770/table2' with 52 column(s) and 1 row(s)
# 	'349:J/MNRAS/476/2117/apogeenn' with 13 column(s) and 1 row(s)
# 	'350:J/MNRAS/485/1067/suppl' with 14 column(s) and 1 row(s)
# 	'351:J/MNRAS/486/251/tablea1' with 20 column(s) and 1 row(s)
# 	'352:J/MNRAS/489/176/dr14ages' with 8 column(s) and 1 row(s)
# 	'353:J/MNRAS/489/2079/table1' with 16 column(s) and 1 row(s)
# 	'354:J/MNRAS/489/2189/table2' with 7 column(s) and 1 row(s)
# 	'355:J/MNRAS/491/2025/table1' with 9 column(s) and 1 row(s)
# 	'356:J/MNRAS/495/3087/catalog' with 15 column(s) and 5 row(s)
# 	'357:J/MNRAS/498/5720/catalog' with 19 column(s) and 50 row(s)
# 	'358:J/MNRAS/503/5263/table10' with 11 column(s) and 3 row(s)
# 	'359:J/MNRAS/504/3730/table2' with 39 column(s) and 1 row(s)
# 	'360:J/MNRAS/505/1476/table1' with 22 column(s) and 1 row(s)
# 	'361:J/MNRAS/505/4496/table6' with 16 column(s) and 1 row(s)
# 	'362:J/MNRAS/507/318/table2' with 15 column(s) and 1 row(s)
# 	'363:J/MNRAS/508/2370/cyg' with 31 column(s) and 1 row(s)
# 	'364:J/MNRAS/515/687/asscyg2' with 13 column(s) and 1 row(s)
# 	'365:J/MNRAS/516/2080/table2' with 17 column(s) and 1 row(s)
# 	'366:J/MNRAS/522/29/table2' with 16 column(s) and 8 row(s)
# 	'367:J/MNRAS/537/1984/a23' with 16 column(s) and 6 row(s)
# 	'368:J/AZh/83/821/osaca' with 13 column(s) and 1 row(s)
# 	'369:J/other/PASA/32.36/lb_evals' with 12 column(s) and 1 row(s)
# 	'370:J/other/RAA/23.I5024/tablea1' with 12 column(s) and 1 row(s)

# %% [markdown]
# We see that this star has data in 354 Vizier tables.  It's not a well-known star.  So you can imagine very well known stars (e.g. Vega, Fomalhaut, Altair, Sirius, etc etc) have data in _a lot_ of tables: it is easy to get lost in the volume of data.So ideally, we would like to down-select to search for data only in specific tables.   Let's do that.
#
# Furthermore, what  Vizier. actually returns is a _table list_ , not a table.  So slicing to get table entries is slightly more complicated vs how we would do it with Simbad tables.
#
# For a first try, let's do the Tycho II catalogue: (I/259/tyc2).

# %%
#result4=Vizier.query_object("HIP 99770",catalog='I/239/tyc_main')
result4=Vizier.query_object("HIP 99770",catalog='I/259/tyc2')
print(result4 ) #what is this table list?
print(len(result4)) #how many entries does it have?
# Out:
# TableList with 1 tables:
# 	'0:I/259/tyc2' with 10 column(s) and 1 row(s)
# 1

# %% [markdown]
# If we want to print out the table entries we can do that here by accessing the relevant subscript of the table.  With the above print statements we learn that this table has only one entry (which is good! There isn't a duplicate HIP 99770 entry floating around this giant catalogue).
#
# See below

# %%
result4[0] #return the first (and only) table
# Out:
# <Table length=1>
#  TYC1  TYC2  TYC3   pmRA     pmDE   ...  VTmag   HIP    RA_ICRS_     DE_ICRS_
#                   mas / yr mas / yr ...   mag             deg          deg
# int16 int16 uint8 float32  float32  ... float32 int32   float64      float64
# ----- ----- ----- -------- -------- ... ------- ----- ------------ ------------
#  2683  3962     1     68.9     71.8 ...   4.962 99770 303.63326583  36.80614139

# %% [markdown]
# Now, the above command just simply selected the first table in the table list.  You can query multiple tables at once: you just have to enclose them in square brackets...
#
# So we are going to query a different Tycho catalog (first entry), the Hipparcos catalog (second entry), and the 2MASS catalog (third entry).  These are all all-sky surveys so they have data for a ton of objects.

# %%
#CAUTION!!! - note the addition of the "Angle" keyword here
result4b=Vizier.query_object("HIP 99770",catalog=['I/239/tyc_main','I/239/hip_main','II/246/out'],radius=Angle(5,"arcsec"))
#                              radius=Angle(1,"deg"))
#result4b
result4b[2] #now return the second of the tables
# Out:
# <Table length=1>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.633484  36.806255 20143203+3648225   4.886   0.306 ...  111  000     0     0

# %% [markdown]
# With this subtlety (Table _list_ vs Table), we can now proceed to return entry values in specific tables.  E.g. ...

# %%
#result4[0].colnames #lists the column names
#result4[0]['TYC'] #returns the column name & all entries in the 'TYC' column
name_tyc=result4b[0]['TYC'][0] #returns the entry for this star
ra_tyc=result4b[0]['RAhms'][0]
vmag=result4b[0]['Vmag'][0]

print(name_tyc)
print(ra_tyc) #note: this is a string as you can see from the table metadata
print(vmag) #floating point
# Out:
# 2683  3962 1
# 20 14 31.98
# 4.95

# %%
result4b[2] #now let's inspect the 3rd table
# Out:
# <Table length=1>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.633484  36.806255 20143203+3648225   4.886   0.306 ...  111  000     0     0

# %%
result4b[2]['Jmag'][0] #return the J band magnitude. #again, note the Angle call in query_object
# Out:
# 4.886

# %% [markdown]
# Arguably the greater power with catalogue queries is searching entire catalogues on condition or querying around a position (any position: doesn't have to be centered on a star).    You can do this with the ``query_region`` function call.

# %%
#from astroquery.vizier import Vizier #already imported this
#from astroquery.coordinates import Angle #already imported this

result5=Vizier.query_region("HIP 99770",radius=Angle(0.15,"deg"),catalog='II/246/out')
result5[0]
# Out:
# <Table length=50>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.686016  36.664169 20144464+3639510  15.489   0.067 ...  220  cc0     0     0
# 303.681316  36.675674 20144351+3640324  16.542      -- ...   11  000     0     0
# 303.685663  36.670895 20144455+3640152  15.872   0.083 ...  111  000     0     0
# 303.685310  36.665012 20144447+3639540  15.758   0.072 ...  220  cc0     0     0
# 303.676842  36.668884 20144244+3640079  15.851   0.081 ...  110  000     0     0
# 303.680029  36.666634 20144320+3639598  15.014   0.039 ...  111  000     0     0
# 303.679284  36.671806 20144302+3640185  16.071      -- ...   11  0cc     0     0
# 303.696010  36.666199 20144704+3639583  14.298   0.027 ...  111  000     0     0
# 303.689185  36.663536 20144540+3639487  14.998   0.046 ...  111  000     0     0
#        ...        ...              ...     ...     ... ...  ...  ...   ...   ...
# 303.672094  36.671692 20144130+3640180  15.477   0.064 ...  111  000     0     0
# 303.671506  36.687038 20144116+3641133  16.495   0.139 ...  100  000     0     0
# 303.669536  36.665558 20144068+3639560  16.029   0.095 ...  111  c00     0     0
# 303.669401  36.680470 20144065+3640496  15.817   0.073 ...  110  ss0     0     0
# 303.664191  36.671028 20143940+3640157  16.133   0.107 ...  200  c00     0     0
# 303.659173  36.661198 20143820+3639403  16.469   0.142 ...  110  000     0     0
# 303.659110  36.663528 20143818+3639487  16.320   0.128 ...  110  000     0     0
# 303.658163  36.665642 20143795+3639563  14.753   0.041 ...  111  000     0     0
# 303.659658  36.679520 20143831+3640462  15.258   0.056 ...  121  0c0     0     0

# %% [markdown]
# Now, if you look at this table you and you know anything about the star we are querying around, you immediately see a problem. Namely, we do not see our star listed (it should be about magnitude 4.5 in each 2MASS passband).
#
# You also see the Table size is 50 (50 entries).   If you make the search radius larger you _still_ get 50 entries.
#
# What's happening here is that a) there are a lot of objects within our search radius and b) astroquery is truncating the entries to 50.
#
# So we must modify our querying ...
#
# First, one thing we can do is tell astroquery to return _all_ row values

# %%
Vizier.ROW_LIMIT = -1   #all values

#Vizier.ROW_LIMIT = 50 #if we want to restore the default
#Vizier.ROW_LIMIT = 100 #if we want to return 100 values

result5b=Vizier.query_region("HIP 99770",radius=Angle(0.15,"deg"),catalog='II/246/out')
result5b[0]
# Out:
# <Table length=4988>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.686016  36.664169 20144464+3639510  15.489   0.067 ...  220  cc0     0     0
# 303.681316  36.675674 20144351+3640324  16.542      -- ...   11  000     0     0
# 303.685663  36.670895 20144455+3640152  15.872   0.083 ...  111  000     0     0
# 303.685310  36.665012 20144447+3639540  15.758   0.072 ...  220  cc0     0     0
# 303.676842  36.668884 20144244+3640079  15.851   0.081 ...  110  000     0     0
# 303.680029  36.666634 20144320+3639598  15.014   0.039 ...  111  000     0     0
# 303.679284  36.671806 20144302+3640185  16.071      -- ...   11  0cc     0     0
# 303.696010  36.666199 20144704+3639583  14.298   0.027 ...  111  000     0     0
# 303.689185  36.663536 20144540+3639487  14.998   0.046 ...  111  000     0     0
#        ...        ...              ...     ...     ... ...  ...  ...   ...   ...
# 303.483484  36.893200 20135603+3653355  14.639   0.045 ...  111  ccc     0     0
# 303.486736  36.892036 20135681+3653313  15.099   0.078 ...  100  c00     0     0
# 303.486202  36.897663 20135668+3653515  14.964   0.048 ...  111  000     0     0
# 303.485031  36.891941 20135640+3653309  11.259   0.021 ...  111  000     0     0
# 303.500670  36.912056 20140016+3654434  15.117   0.047 ...  111  000     0     0
# 303.507024  36.912502 20140168+3654450  14.003   0.040 ...  220  cc0     0     0
# 303.504921  36.910526 20140118+3654378  15.688   0.075 ...  111  000     0     0
# 303.511428  36.919178 20140274+3655090  11.556   0.021 ...  111  0dd     0     0
# 303.506011  36.914890 20140144+3654536  12.106   0.021 ...  111  000     0     0

# %% [markdown]
# We can also return a _sorted_ table by adding a ``+`` or ``-`` in front of column names.   Let's sort on the J band magnitude.

# %%
#note * means "standard columns" ... otherwise you would only return the Jmag column
v=Vizier(columns=["*","+Jmag"],catalog="II/246/out")
v.ROW_LIMIT = -1

result5c=v.query_region("HIP 99770",radius=Angle(0.15,"deg"),catalog='II/246/out')
result5c[0]
# Out:
# <Table length=4988>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.665097  36.752087 20143962+3645075   4.552   0.276 ...  111  000     0     0
# 303.633484  36.806255 20143203+3648225   4.886   0.306 ...  111  000     0     0
# 303.799735  36.863590 20151193+3651489   6.802   0.023 ...  111  000     0     0
# 303.632409  36.661018 20143177+3639396   6.980   0.027 ...  111  000     0     0
# 303.801214  36.769802 20151229+3646112   7.551   0.018 ...  111  000     0     0
# 303.638422  36.915199 20143322+3654547   8.341   0.020 ...  111  000     0     0
# 303.730587  36.722252 20145534+3643201   8.412   0.019 ...  111  000     0     0
# 303.687070  36.691135 20144489+3641280   8.585   0.018 ...  111  000     0     0
# 303.501693  36.779751 20140040+3646471   8.611   0.027 ...  111  000     0     0
#        ...        ...              ...     ...     ... ...  ...  ...   ...   ...
# 303.637173  36.711529 20143292+3642415  17.595      -- ...   11  000     0     0
# 303.512664  36.739227 20140303+3644212  17.639      -- ...   10  000     0     0
# 303.645565  36.810493 20143493+3648377  17.646   0.487 ...  220  cc0     0     0
# 303.690147  36.783302 20144563+3646598  17.739      -- ...   11  000     0     0
# 303.808742  36.804085 20151409+3648147  17.769      -- ...   10  000     0     0
# 303.672829  36.688778 20144147+3641196  17.822      -- ...   11  000     0     0
# 303.718747  36.737339 20145249+3644144  17.848      -- ...    1  000     0     0
# 303.700020  36.680519 20144800+3640498  17.947      -- ...   11  0ss     0     0
# 303.698516  36.742397 20144764+3644326  18.149      -- ...   11  00c     0     0

# %% [markdown]
# Now, it's not entirely clear which entry is the one we want from this list just from looking at it.  Is it the first or second entry?
#
# If we compare with the Simbad position output we see that it is the second.

# %%
starcoords=Simbad.query_object("HIP 99770")
print(starcoords[0]['RA'],starcoords[0]['DEC'])
# Out:
# 20 14 32.0323 +36 48 22.700

# %% [markdown]
# Finally, the most obvious thing to do is to just shrink our search radius.  If you do so, you (naturally) return fewer stars.  So let's shrink the radius to 20 arcseconds

# %%
result5d=v.query_region("HIP 99770",radius=Angle(20,"arcsec"),catalog='II/246/out')
result5d[0]
# Out:
# <Table length=2>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.633484  36.806255 20143203+3648225   4.886   0.306 ...  111  000     0     0
# 303.627252  36.807613 20143054+3648274  12.677      -- ...    2  00c     0     0

# %% [markdown]
# _Now_ it is clearer which entry we want.
#
# We also could have kept the search radius the same but added _column filters_ to downselect on objects that "might" be the one(s) we are interested in.   See below ...

# %%
result5e=v.query_region("HIP 99770",radius=Angle(0.15,"deg"),catalog='II/246/out',column_filters={"Jmag":"<6"})
print(result5e[0])
# Out:
#  RAJ2000    DEJ2000        _2MASS       Jmag  e_Jmag ... Bflg Cflg Xflg Aflg
#    deg        deg                       mag    mag   ...
# ---------- ---------- ---------------- ------ ------ ... ---- ---- ---- ----
# 303.665097  36.752087 20143962+3645075  4.552  0.276 ...  111  000    0    0
# 303.633484  36.806255 20143203+3648225  4.886  0.306 ...  111  000    0    0

# %%
#slightly more complex

#the two dots define a range
result5f=v.query_region("HIP 99770",radius=Angle(0.15,"deg"),catalog='II/246/out',
                         column_filters={"Jmag":"4 .. 9.7"})
print(result5f[0])
# Out:
#  RAJ2000    DEJ2000        _2MASS       Jmag  e_Jmag ... Bflg Cflg Xflg Aflg
#    deg        deg                       mag    mag   ...
# ---------- ---------- ---------------- ------ ------ ... ---- ---- ---- ----
# 303.665097  36.752087 20143962+3645075  4.552  0.276 ...  111  000    0    0
# 303.633484  36.806255 20143203+3648225  4.886  0.306 ...  111  000    0    0
# 303.799735  36.863590 20151193+3651489  6.802  0.023 ...  111  000    0    0
# 303.632409  36.661018 20143177+3639396  6.980  0.027 ...  111  000    0    0
# 303.801214  36.769802 20151229+3646112  7.551  0.018 ...  111  000    0    0
# 303.638422  36.915199 20143322+3654547  8.341  0.020 ...  111  000    0    0
# 303.730587  36.722252 20145534+3643201  8.412  0.019 ...  111  000    0    0
# 303.687070  36.691135 20144489+3641280  8.585  0.018 ...  111  000    0    0
# 303.501693  36.779751 20140040+3646471  8.611  0.027 ...  111  000    0    0
#        ...        ...              ...    ...    ... ...  ...  ...  ...  ...
# 303.517851  36.918816 20140428+3655077  9.153  0.021 ...  111  000    0    0
# 303.639025  36.671207 20143336+3640163  9.173  0.030 ...  111  000    0    0
# 303.509660  36.801949 20140231+3648070  9.306  0.020 ...  111  000    0    0
# 303.730555  36.853554 20145533+3651127  9.338  0.021 ...  111  000    0    0
# 303.741286  36.833282 20145790+3649598  9.340  0.021 ...  111  000    0    0
# 303.744294  36.702522 20145863+3642090  9.352  0.019 ...  111  000    0    0
# 303.660464  36.874016 20143851+3652264  9.464  0.021 ...  111  000    0    0
# 303.629100  36.873882 20143098+3652259  9.598  0.021 ...  111  000    0    0
# 303.784785  36.780125 20150834+3646484  9.639  0.021 ...  111  000    0    0
# 303.473318  36.760235 20135359+3645368  9.691  0.020 ...  111  000    0    0
# Length = 24 rows

# %% [markdown]
# Now, we don't actually have to center the search on the position of a known object.  We can center it on blank space, provided that put in a coordinate object in our Vizier call.   Here's what I mean ...

# %%
#let's select a region just slightly off HIP 99770, about halfway between it and the other bright star
blankspace=SkyCoord('20h14m37.0s','+36d46m00.0s')
blankspace
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (303.65416667, 36.76666667)>

# %%
v2=Vizier(columns=["*","+Jmag"])

result6=v2.query_region(blankspace,
   radius=Angle(1,"deg"),catalog='II/246/out',column_filters={"Jmag":"<18"})

result6[0]
# Out:
# <Table length=50>
#  RAJ2000    DEJ2000        _2MASS        Jmag   e_Jmag ... Bflg Cflg  Xflg  Aflg
#    deg        deg                        mag     mag   ...
#  float64    float64        str17       float32 float32 ... str3 str3 uint8 uint8
# ---------- ---------- ---------------- ------- ------- ... ---- ---- ----- -----
# 303.665097  36.752087 20143962+3645075   4.552   0.276 ...  111  000     0     0
# 302.781041  36.130852 20110744+3607510   4.559   0.242 ...  111  000     0     0
# 302.736799  36.579788 20105683+3634472   4.688   0.274 ...  111  000     0     0
# 304.849469  36.729591 20192387+3643465   4.836   0.186 ...  111  000     0     0
# 303.633484  36.806255 20143203+3648225   4.886   0.306 ...  111  000     0     0
# 302.775625  36.113567 20110615+3606488   5.033   0.017 ...  111  000     0     0
# 303.057928  35.979988 20121390+3558479   5.050   0.306 ...  111  000     0     0
# 303.527681  36.278870 20140664+3616439   5.141   0.026 ...  111  000     0     0
# 303.872403  37.019821 20152937+3701113   5.180   0.240 ...  111  000     0     0
#        ...        ...              ...     ...     ... ...  ...  ...   ...   ...
# 303.150233  36.263226 20123605+3615476   6.538   0.021 ...  111  000     0     0
# 303.418414  36.128975 20134041+3607443   6.555   0.024 ...  111  000     0     0
# 303.769947  37.695835 20150478+3741450   6.600   0.019 ...  111  000     0     0
# 304.779575  36.752174 20190709+3645078   6.603   0.030 ...  111  000     0     0
# 304.220168  37.518013 20165284+3731048   6.605   0.021 ...  111  000     0     0
# 303.035453  35.937111 20120850+3556135   6.612   0.020 ...  111  000     0     0
# 302.586702  36.641197 20102080+3638283   6.613   0.024 ...  111  000     0     0
# 302.754937  36.700607 20110118+3642021   6.635   0.018 ...  111  000     0     0
# 303.394896  35.852814 20133477+3551101   6.651   0.021 ...  111  000     0     0

# %% [markdown]
# ### Other Queries
#
# There are other databases you can query.  One major one is the Gaia database which has its own subpackage.   I will try to add notes on this later.

# %% [markdown]
# ### Some Examples of Doing Science with Database Queries
#
# So how would you actually use this in real code?   Below is one example:
# * an abbreviated example copied and pasted from some code that I wrote two years ago to select targets.  It has an input file and then queries the Simbad and Vizier databases

# %%
#Example 

#uses IDL output of HGCA accelerators, queries Simbad to get the spectral type, queries Gaia-eDR3 to get photometry, saves to output
import astroquery
import numpy as np
from astroquery.simbad import Simbad
from astroquery.vizier import Vizier
from astropy.io import ascii
import astropy.units as u
import astropy.coordinates as coord
from astropy.table import QTable
#from astroquery.utils.tap.core import TapPlus
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord,Angle

infile='astars_100pc'
Gaia.MAIN_GAIA_TABLE = "gaiaedr3.gaia_source"
radius=u.Quantity(1.5/3600.0,u.deg)

def add_gaia_data(infile):

    outfile=infile+'_plus_gaia_and_cahkv2'

    #formatted loading
    dtypes={'names': ('name1','name2','ra1','ra2','ra3','dec1','dec2','dec3','distance','spt','mass','chisq'),\
       'formats':('U20','U20',np.int64,np.int64,np.float64,np.int64,np.int64,np.float64,np.float64,'U20',np.float64,np.float64)}

    a= np.loadtxt(infile,usecols=range(12),dtype=dtypes)

    #combining the first two strings to get the target name
    names = np.array([ '{0} {1}'.format( x, y ) for x,y in zip( a['name1'], a['name2'] ) ])
    names =np.array(names,dtype=str)

    mass=a['mass']
    chisq=a['chisq']
    #determine ra and dec
    ra_deg=(a['ra1']+a['ra2']/60.+a['ra3']/3600.)*15
    dec_deg=(np.abs(a['dec1'])+np.abs(a['dec2']/60.)+np.abs(a['dec3']/3600.))

    pos = a['dec1'] >= 0
    neg = (a['dec1'] < 0) | (a['dec2'] < 0)
    print(len(neg))
    dec_deg[neg]=-1*dec_deg[neg]


    nstar=len(dec_deg)

    plx=np.zeros(nstar)
    gmag=np.zeros(nstar)
    bp_rp=np.zeros(nstar)
    ra=np.zeros(nstar)
    dec=np.zeros(nstar)
    bmv=np.zeros(nstar)
    hkact=np.zeros(nstar)

    Simbad.add_votable_fields('sptype')
    Simbad.timeout=60
    Vizier.timeout=60

    spt= ["" for i in range(nstar)]
    for i in range(nstar):
       print('processing star number ',i,' star name ',names[i])

       #simbad
       try:
        results=Simbad.query_object(names[i])
       except:
        print('!!!!!Error on ',names[i])
        continue
       spt[i]=results['SP_TYPE'][0]

       coord=SkyCoord(ra=ra_deg[i],dec=dec_deg[i],unit=(u.degree,u.degree),frame='icrs')
       r=Gaia.cone_search(coord,radius=radius)
       j=r.get_results()
       try:
         ra[i]=j['ra'][0]
         dec[i]=j['dec'][0]
#         print('found star ',i,names[i],ra_deg[i],dec_deg[i],(a['dec1'])[i],(a['dec2'])[i],(a['dec3'])[i])
       except:
         print('missing star ',i,names[i],ra_deg[i],dec_deg[i],(a['dec1'])[i],(a['dec2'])[i],(a['dec3'])[i])
         continue
       plx[i]=j['parallax'][0]
       gmag[i]=j['phot_g_mean_mag'][0]
       bp_rp[i]=j['bp_rp'][0]

       #now, pull Tycho II catalog
       result=Vizier.query_region(SkyCoord.from_name(names[i]),radius=Angle(5/3600.,"deg"),catalog=['I/259/tyc2'])
       #print(result)
       #result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['I/259/tyc2'])
       #print(result[0]['BTmag'][0])

       if len(result) >= 1:
         btmag=result[0]['BTmag'][0]
         vtmag=result[0]['VTmag'][0]
         bmag,vmag=tycho_convert(btmag,vtmag)
         #print(bmag,vmag,btmag,vtmag)
       else:
         bmag= -99
         vmag=-109

       caHK=99 #initializing to NaN

       #now, pull catalogs to find if the star has an activity measurement
       #Pace+2013
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/A+A/551/L8'])
       try:
         caHK=0.5*(result[0]['logRmin'][0]+result[0]['logRmax'][0])
       except:
         caHK=99

       #Gondoin+2020
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/A+A/641/A110'])
       try:
          newHK=result[0]["logR'HK"][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Hojjatpanah+2020
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/A+A/639/A35'])
       try:
          newHK=result[0]["logR'HK"][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Hojjatpanah+2019
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/A+A/629/A80'])
       try:
          newHK=result[0]["logR'HK"][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Lick Planet Search 2010
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/ApJ/725/875/table1'])
       try:
          newHK=result[0]['logRHK'][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Gray/Nstars-south

       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/AJ/132/161'])
       try:
          newHK=result[0]['logR'][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Gray/Nstars-north

       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/AJ/126/2048'])
       try:
          newHK=result[0]["logR'HK"][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Boro Saikia+2018
       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/A+A/616/A108'])
       try:
          newHK=result[0]['logRpHK'][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #Hinkel+2017

       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/ApJ/848/34'])
       try:
          newHK=result[0]['logRpHK'][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99

       #White and Hillenbrand 2007

       result=Vizier.query_object(names[i],radius=Angle(5/3600.,"deg"),catalog=['J/AJ/133/2524'])
       try:
          newHK=result[0]['logRHK'][0]
          caHK=np.minimum(caHK,newHK)
       except:
          newHK=99


       hkact[i]=caHK
       bmv[i]=bmag-vmag
       print('bmv and CaHK for ',names[i],' are ',bmv[i],hkact[i])

    gmag_abs=np.array(gmag-5*np.log10(1e2/plx))

    f=open(outfile,'w')
    for i in range(len(ra)):
       f.write("%s %.3s %f %f %f %f %f %f %f %f %f %f\n" % (names[i].replace(" ",""),spt[i],mass[i],chisq[i],ra[i],dec[i],plx[i],gmag_abs[i],gmag[i],bp_rp[i],bmv[i],hkact[i]))
       #f.write("%s %f %f %f %f %f %f\n" % (names[i].replace(" ",""),ra[i],dec[i],plx[i],gmag_abs[i],gmag[i],bp_rp[i]))

    f.close()

def tycho_convert(BT,VT):
      v=VT-0.09*(BT-VT)
      b=v+0.85*(BT-VT)

      return b, v

# %%
directory='./code/sect3/files/'
filename='gkm_30pctest'
add_gaia_data(directory+filename)
# Out:
# 10
# processing star number  0  star name  HIP 522
# bmv and CaHK for  HIP 522  are  0.4606998443603514 -4.77036496665
# processing star number  1  star name  HIP 669
# bmv and CaHK for  HIP 669  are  0.5754500389099118 -4.7779998779296875
# processing star number  2  star name  HIP 1068
# bmv and CaHK for  HIP 1068  are  10.0 99.0
# processing star number  3  star name  HIP 1349
# bmv and CaHK for  HIP 1349  are  0.5865000486373901 -4.75032990602
# processing star number  4  star name  HIP 1444
# bmv and CaHK for  HIP 1444  are  0.5516501426696774 -5.30448706779
# processing star number  5  star name  HIP 1598
# bmv and CaHK for  HIP 1598  are  0.5847997665405273 -4.923999786376953
# processing star number  6  star name  HIP 2790
# bmv and CaHK for  HIP 2790  are  0.7029497146606438 -4.89611434898
# processing star number  7  star name  HIP 3008
# bmv and CaHK for  HIP 3008  are  1.2078495979309078 99.0
# processing star number  8  star name  HIP 3588
# bmv and CaHK for  HIP 3588  are  1.2095494747161872 -4.58653262788
# processing star number  9  star name  HIP 3879
# bmv and CaHK for  HIP 3879  are  1.1746999740600579 -4.36561680453

# %% [markdown]
# This creates a file that we can read in ...

# %%
from math import exp, log10

directory='./code/sect3/files/'
file0='gkm_30pctest_plus_gaia_and_cahkv2'
def run(infile=file0):
   table=np.loadtxt(directory+infile,dtype=np.unicode_)
   hgca_name=table[:,0]
   hgca_bmv=table[:,10].astype(float)
   hgca_cahk=table[:,11].astype(float)
   hgca_mass=table[:,2].astype(float)
   hgca_ra=table[:,4].astype(float)
   hgca_dec=table[:,5].astype(float)
   plx=table[:,6].astype(float)

   print(hgca_ra[0:5])
   print(hgca_dec[0:5])

   detectable= np.where( (hgca_mass > 5.0) & (hgca_mass < 30))
   lowmass=np.where((hgca_mass < 5.0) & (hgca_mass > 1.0))
   c1='lightgray'
   m1='.'
   #label1='HGCA stars ($M_{comp, 0.5 arcsec}$ = $1-5 M_{J}$)'

   c2='lime'
   m2='.'
   label2='HGCA stars ($M_{comp, 0.5 arcsec}$ = 1-5 $M_{J}$)'

   c3='magenta'
   m3='.'
   label3='HGCA stars ($M_{comp, 0.5 arcsec}$ = 5-30 $M_{J}$)'
   plt.xlim(0.45,0.9)
   plt.ylim(-5.5,-3.25)
   plt.xlabel("B-V")
   plt.ylabel("log(R'HK)")
   hyades_bmv=[0.5,0.9]
   pleiades_bmv=[0.5,0.8]
   hyades_cahk=[-4.55,-4.45]
   pleiades_cahk=[-4.4,-4.2]
   m67_bmv=[0.5,0.8]
   m67_cahk=[-4.8,-4.8]
   plt.plot(m67_bmv,m67_cahk,'-',zorder=1,label='M67 (3.5 Gyr)',c='black')
   plt.plot(hyades_bmv,hyades_cahk,'--',zorder=1,label='Hyades (800 Myr)')
   plt.plot(pleiades_bmv,pleiades_cahk,'-.',zorder=1,label='Pleiades (110 Myr)')

   plt.scatter(hgca_bmv,hgca_cahk,marker=m1,c=c1,s=30*hgca_mass/2,zorder=2)
   plt.scatter(hgca_bmv[detectable],hgca_cahk[detectable],marker=m3,c=c3,label=label3,s=50*hgca_mass[detectable]/2,zorder=2)
   plt.scatter(hgca_bmv[lowmass],hgca_cahk[lowmass],marker=m2,c=c2,label=label2,s=50*hgca_mass[lowmass]/2,zorder=2)
   plt.legend(loc='upper left',fontsize=8.5)

    
run()
# Out:
# [1.583799 2.068107 3.325006 4.226865 4.497121]
# [-49.075368 -14.824541  69.32568  -52.650335 -13.455642]

# %% [markdown]
# A fuller version of this plot (where I didn't truncate the sample), looks like the following...
#
# ![png](./code/sect3/figures/cahk.png)
